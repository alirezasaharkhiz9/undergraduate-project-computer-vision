# %% [markdown]
# <a href="https://colab.research.google.com/github/alirezasaharkhiz9/undergraduate-project-computer-vision/blob/main/Modern%20Computer%20Vision/ObjectDetectionUsingYOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Detection Using YOLO v8

# %% [markdown]
# ## About Dataset
#
# ------------------
#
# #### Bone Fracture Detection
#
# A comprehensive dataset of X-ray images was created for bone fracture detection, specifically designed for computer vision projects. The primary goal of this dataset is to aid in developing and evaluating algorithms for automated bone fracture detection.
#
# The dataset contains images categorized into different classes, each representing a specific type of bone fracture. These classes include Elbow Positive, Fingers Positive, Forearm Fracture, Humerus Fracture, Shoulder Fracture, and Wrist Positive.
#
# Each image in the dataset is annotated with either bounding boxes or pixel-level segmentation masks to indicate the location and extent of the detected fracture. This facilitates the training and evaluation of bone fracture detection algorithms.
#
# The bone fracture detection dataset is a useful resource for researchers and developers who want to train machine learning models, specifically focusing on object detection algorithms, to automatically detect and classify bone fractures in X-ray images. The dataset's diversity of fracture classes enables the development of robust models capable of accurately identifying fractures in different regions of the upper extremities.
#
# The aim of creating this dataset is to accelerate the development of computer vision solutions for automated fracture detection, supporting advancements in medical diagnostics and improving patient care.

# %% [markdown]
# ## Train YOLOv8 Model

# %%
pwd
# Out:
# '/teamspace/studios/this_studio'

# %%
ls
# Out:
#  AutoEncoderWithKeras.ipynb*
#  Chest-X-Ray/
# 'EfficientNetB0-100-(224 X 224)- 97.59.h5'*
#  EutoEncoderWithKeras.h5*
#  Game.ipynb*
#  GanWithPytorch.ipynb*
#  LosAngeles2022-101.jpg*
#  LungsSegmentationUsingU-Net.h5*
#  LungsSegmentationUsingU_Net.ipynb*
#  MetaData.csv*
#  YOLOv11/
#  YOLOv11.ipynb
#  YOLOv5/
#  YOLOv5.ipynb*
# 'butterflies and moths.csv'*
#  butterfly-images40-species.zip*
#  chest-x-ray-lungs-segmentation.zip*
#  dataset/
#  dogs-vs-cats.zip*
#  inception_training.h5*
# 'landscape Images'/
#  landscape-image-colorization.zip*
#  lightning_logs/
#  lungvision.zip*
#  resnet.h5*
#  street_image.jpg*
#  test/
#  train/
#  training.csv.csv*
#  valid/

# %%
import os
os.chdir('/teamspace/studios/this_studio/YOLOv11/')
# !pwd
# Out:
# /teamspace/studios/this_studio/YOLOv11

# %%
# !pip install roboflow -q

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DT65foAZCyxoW7FfX1Rd")
project = rf.workspace("alireza-saharkhiz-he3nr").project("bone-fracture-detection-1yyjs")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Bone-Fracture-Detection-3 in yolov11:: 100%|██████████| 7046/7046 [00:01<00:00, 6502.24it/s]

# %%
# !pip install ultralytics -q

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.10 torch-2.2.1+cu121 CPU (Intel Xeon Platinum 8488C)
# Setup complete ✅ (4 CPUs, 15.3 GB RAM, 56.0/387.5 GB disk)

# %%
import os
os.chdir('/teamspace/studios/this_studio/YOLOv11/Bone-Fracture-Detection-3')
# !pwd
# Out:
# /teamspace/studios/this_studio/YOLOv11/Bone-Fracture-Detection-3

# %%
from ultralytics import YOLO
import os

model = YOLO('yolov8m.pt')

# Train the model
model.train(task='detect', mode='train', data='data.yaml', epochs=60, device=0)
#  device=0
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 193MB/s]
# New https://pypi.org/project/ultralytics/8.3.58 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.55 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA L40S, 45596MiB)
# ...

# %%
# Validate the model
metrics = model.val()

# Print the evaluation metrics
print("Model Evaluation Metrics:", metrics)
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA L40S, 45596MiB)
# Model summary (fused): 218 layers, 25,843,813 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /teamspace/studios/this_studio/YOLOv11/Bone-Fracture-Detection-3/valid/labels.cache... 403 images, 0 backgrounds, 0 corrupt: 100%|██████████| 403/403 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:03<00:00,  8.57it/s]
#                    all        403        462      0.628      0.699      0.729      0.422
#         elbow positive         57         62      0.636      0.565      0.537      0.352
#       fingers positive         39         50      0.797       0.72      0.822      0.467
#       forearm fracture         94        103      0.688      0.602      0.649      0.276
#                humerus        109        114      0.739      0.702       0.74      0.359
# ...

# %% [markdown]
# ## Result

# %% [markdown]
# ![results.png](data:image/png;base64,...)

# %% [markdown]
# ![confusion_matrix.png](data:image/png;base64,...)

# %%
import cv2
import matplotlib.pyplot as plt

image1 = cv2.imread('/content/val_batch0_labels.jpg')
image2 = cv2.imread('/content/val_batch0_pred.jpg')

image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.imshow(image1)
plt.title('val label')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image2)
plt.title('val predict')
plt.axis('off')

plt.show()

# %%
image1 = cv2.imread('/content/val_batch1_labels.jpg')
image2 = cv2.imread('/content/val_batch1_pred.jpg')

image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.imshow(image1)
plt.title('val label')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image2)
plt.title('val predict')
plt.axis('off')

plt.show()

# %%
image1 = cv2.imread('/content/val_batch2_labels.jpg')
image2 = cv2.imread('/content/val_batch2_pred.jpg')

image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.imshow(image1)
plt.title('val label')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image2)
plt.title('val predict')
plt.axis('off')

plt.show()
