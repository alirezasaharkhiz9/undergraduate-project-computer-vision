# %% [markdown]
# # Pose Estimation With Yolo

# %% [markdown]
# ## Load dataset and model

# %%
pwd
# Out:
# '/teamspace/studios/this_studio'

# %%
import os

os.chdir('/teamspace/studios/this_studio/Pose Estimation')

# !pwd
# Out:
# /teamspace/studios/this_studio/Pose Estimation

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DT65foAZCyxoW7FfX1Rd")
project = rf.workspace("mukilan").project("human-activity-ce7zu-ndqdc-jmfki-szqfk-n3pbo")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Human-activity-1 in yolov8:: 100%|██████████| 4028/4028 [00:00<00:00, 7812.37it/s]

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11s-pose.pt')
# Out:
# ...
# 100%|██████████| 19.4M/19.4M [00:00<00:00, 206MB/s]

# %% [markdown]
# ## Fine-Tuning

# %%
rm -r runs

# %%
result = model.train(
    data = 'Human-activity-1/data.yaml',
    task = 'pose',
    mode = 'train',
    epochs = 100
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.68 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.55 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA L40S, 45596MiB)
# ...

# %% [markdown]
# ## Result

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA L40S, 45596MiB)
# YOLO11s-pose summary (fused): 257 layers, 9,904,488 parameters, 0 gradients, 23.1 GFLOPs
# val: Scanning /teamspace/studios/this_studio/Pose Estimation/Human-activity-1/valid/labels.cache... 421 images, 2 backgrounds, 0 corrupt: 100%|██████████| 421/421 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 27/27 [00:03<00:00,  7.69it/s]
#                    all        421        422      0.937       0.94      0.969      0.819       0.91      0.867      0.912      0.682
#              Fall-Down         91         91      0.986      0.956       0.99      0.897      0.966      0.924      0.955      0.752
#                Sitting        104        104      0.971          1      0.993       0.92       0.94      0.952      0.971      0.774
# ...

# %%
import os
os.chdir('/teamspace/studios/this_studio/Pose Estimation/runs/pose')
# !pwd
# Out:
# /teamspace/studios/this_studio/Pose Estimation/runs/pose

# %%
import cv2
import matplotlib.pyplot as plt

image1 = cv2.imread('train/confusion_matrix.png')

image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 10))

plt.imshow(image1)
plt.title('confusion matrix')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image1 = cv2.imread('train2/val_batch0_labels.jpg')
image2 = cv2.imread('train2/val_batch0_pred.jpg')

image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.imshow(image1)
plt.title('val label')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image2)
plt.title('val predict')
plt.axis('off')

plt.show()

# %%
image1 = cv2.imread('train2/val_batch1_labels.jpg')
image2 = cv2.imread('train2/val_batch1_pred.jpg')

image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.imshow(image1)
plt.title('val label')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image2)
plt.title('val predict')
plt.axis('off')

plt.show()

# %%
from ultralytics import YOLO

# %%
path_model = 'train/weights/best.pt'
model = YOLO(path_model)

# %%
import os

os.chdir('/teamspace/studios/this_studio/Pose Estimation')

# !pwd
# Out:
# /teamspace/studios/this_studio/Pose Estimation

# %%
model.predict(
    source = 'Human-activity-1/test/images',
    save = True
)
# Out:
# image 1/208 /teamspace/studios/this_studio/Pose Estimation/Human-activity-1/test/images/10_jpg.rf.87ce5a473392c4d164d004542d9c08e5.jpg: 640x640 1 running, 180.1ms
# image 2/208 /teamspace/studios/this_studio/Pose Estimation/Human-activity-1/test/images/11_jpg.rf.2e431d5f8200a3e6e87e6c981071a62c.jpg: 640x640 1 running, 154.5ms
# image 3/208 /teamspace/studios/this_studio/Pose Estimation/Human-activity-1/test/images/12_jpg.rf.c4b42934291cced5aa2cd799533c6ed7.jpg: 640x640 1 running, 154.0ms
# image 4/208 /teamspace/studios/this_studio/Pose Estimation/Human-activity-1/test/images/13_jpg.rf.fa2279e8b60df528dc462c4f899396db.jpg: 640x640 1 running, 167.0ms
# image 5/208 /teamspace/studios/this_studio/Pose Estimation/Human-activity-1/test/images/14_jpg.rf.df28291220425ce70ec2116d62dbdf90.jpg: 640x640 1 running, 151.8ms
# image 6/208 /teamspace/studios/this_studio/Pose Estimation/Human-activity-1/test/images/15_jpg.rf.5377fb23c1ab522948a4c915152aacaa.jpg: 640x640 1 running, 153.9ms
# ...

# %%
import cv2
import matplotlib.pyplot as plt

image1 = cv2.imread('runs/pose/predict/44_jpg.rf.55af1b637473b32d213057fa8ab3163f.jpg')
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image1)
plt.title('predict')

plt.show()

# %%
image1 = cv2.imread('runs/pose/predict/clideo_editor_454ae88c0d8f4113a208876eb58e9b67_mp4-0799_jpg.rf.6b793850c44cfd1f74fb3278879be335.jpg')
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image1)
plt.title('predict')

plt.show()

# %%
image1 = cv2.imread('runs/pose/predict/Screenshot-2024-09-25-at-8-43-41-PM_png.rf.486b076dc019f0947c68ab5627d21aab.jpg')
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image1)
plt.title('predict')

plt.show()

# %%
image1 = cv2.imread('runs/pose/predict/13_jpg.rf.fa2279e8b60df528dc462c4f899396db.jpg')
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image1)
plt.title('predict')

plt.show()
